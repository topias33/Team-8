# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os, shutil

orig_dir = 'chest_xray/train'
orig_dir2 = 'chest_xray/test'

# %% [markdown]
# Remove existing directories and make new directories.

# %%
# %%time
train_dir = './train'
valid_dir = './validation'
test_dir = './test'

for d in [train_dir, valid_dir, test_dir]:
    if os.path.exists(d):
        shutil.rmtree(d)
    os.mkdir(d)
    os.mkdir(os.path.join(d,'NORMAL'))
    os.mkdir(os.path.join(d,'PNEUMONIA'))
print(os.listdir(train_dir))
# Out:
# ['NORMAL', 'PNEUMONIA']
# Wall time: 1.4 s

# %% [markdown]
# List all normal and pneumonia image paths in original train and test data.

# %%
# %%time
normal_images = [os.path.join(orig_dir, 'NORMAL', x) for x in os.listdir(os.path.join(orig_dir, 'NORMAL')) if x.endswith('.jpeg')]
normal_images += [os.path.join(orig_dir2, 'NORMAL', x) for x in os.listdir(os.path.join(orig_dir2, 'NORMAL')) if x.endswith('.jpeg')]
pneumonia_images = [os.path.join(orig_dir, 'PNEUMONIA', x) for x in os.listdir(os.path.join(orig_dir, 'PNEUMONIA')) if x.endswith('.jpeg')]
pneumonia_images += [os.path.join(orig_dir2, 'PNEUMONIA', x) for x in os.listdir(os.path.join(orig_dir2, 'PNEUMONIA')) if x.endswith('.jpeg')]


print(len(normal_images))
print(len(pneumonia_images))
# Out:
# 1583
# 4273
# Wall time: 37.9 ms

# %%
print(normal_images[0])
print(normal_images[0].split('\\')[-1])
# Out:
# chest_xray/train\NORMAL\IM-0115-0001.jpeg
# IM-0115-0001.jpeg

# %% [markdown]
# Randomize the order of the images.

# %%
# %%time
random.shuffle(normal_images)
random.shuffle(pneumonia_images)
# Out:
# Wall time: 0 ns

# %% [markdown]
# Copy the images from original directories to new ones and split them into train, validation and test folders. (0.6 : 0.2 : 0.2)

# %%
# %%time
split = int(0.2 * len(normal_images))
for file in normal_images[:split]:
    shutil.copyfile(file, os.path.join(test_dir, 'NORMAL', file.split('\\')[-1]))

for file in normal_images[split:split * 2]:
    shutil.copyfile(file, os.path.join(valid_dir, 'NORMAL', file.split('\\')[-1]))
    
for file in normal_images[split * 2:]:
    shutil.copyfile(file, os.path.join(train_dir, 'NORMAL', file.split('\\')[-1]))
# Out:
# Wall time: 3.44 s

# %%
# %%time
split = int(0.2 * len(pneumonia_images))
for file in pneumonia_images[:split]:
    shutil.copyfile(file, os.path.join(test_dir, 'PNEUMONIA', file.split('\\')[-1]))

for file in pneumonia_images[split:split * 2]:
    shutil.copyfile(file, os.path.join(valid_dir, 'PNEUMONIA', file.split('\\')[-1]))
    
for file in pneumonia_images[split * 2:]:
    shutil.copyfile(file, os.path.join(train_dir, 'PNEUMONIA', file.split('\\')[-1]))
# Out:
# Wall time: 4.76 s

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

scale = 1./255
datagen = ImageDataGenerator(rescale=scale)

# %%
target_size = (150,150)
batch_size = 16
class_mode = 'binary'

train_generator = datagen.flow_from_directory(
    train_dir, target_size,
    batch_size=batch_size,
    class_mode=class_mode,
    shuffle=False)

dev_generator = datagen.flow_from_directory(
    valid_dir, target_size,
    batch_size=batch_size,
    class_mode=class_mode,
    shuffle=False)

test_generator = datagen.flow_from_directory(
    test_dir, target_size,
    batch_size=batch_size,
    class_mode=class_mode,
    shuffle=False)
# Out:
# Found 3516 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.
# Found 1170 images belonging to 2 classes.

# %%
data_batch = train_generator[0][0]
imshow(data_batch[0])
show()
data_batch[0].shape
# Out:
# (150, 150, 3)

# %%
#Build and compile the model

from tensorflow.keras import models, layers

network = models.Sequential()
network.add(layers.Conv2D(32, (3,3), activation = 'relu', padding = "same",input_shape=data_batch[0].shape))
network.add(layers.MaxPooling2D((2,2)))
network.add(layers.Conv2D(32, (3,3), activation = 'relu'))
network.add(layers.MaxPooling2D((2,2)))
network.add(layers.Conv2D(32, (3,3), padding = "same", activation = 'relu'))
network.add(layers.MaxPooling2D((2,2)))
network.add(layers.Flatten())
network.add(layers.Dense(1, activation = 'sigmoid'))

network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 73, 73, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 36, 36, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 10369
# =================================================================
# Total params: 29,761
# Trainable params: 29,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.metrics import SensitivityAtSpecificity

network.compile(loss='binary_crossentropy', metrics=[SensitivityAtSpecificity(0.9)])

# %%
steps_per_epoch = int(train_generator.samples / batch_size)
validation_steps = int(dev_generator.samples / batch_size)

print(steps_per_epoch, validation_steps)
# Out:
# 219 73

# %%
epochs = 50

# %%
# %%time
history = network.fit_generator(train_generator,
                                workers=4,
                                steps_per_epoch=steps_per_epoch,
                                verbose=1,
                                epochs=epochs,
                                validation_data=dev_generator,
                                validation_steps=validation_steps)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 131s 600ms/step - loss: 0.5879 - sensitivity_at_specificity: 0.3142 - val_loss: 0.2961 - val_sensitivity_at_specificity: 0.7852
# Epoch 2/50
# 219/219 [==============================] - 133s 607ms/step - loss: 0.3410 - sensitivity_at_specificity: 0.7809 - val_loss: 0.2096 - val_sensitivity_at_specificity: 0.9484
# Epoch 3/50
# 219/219 [==============================] - 128s 584ms/step - loss: 0.2443 - sensitivity_at_specificity: 0.8686 - val_loss: 0.1928 - val_sensitivity_at_specificity: 0.9636
# Epoch 4/50
# 219/219 [==============================] - 128s 585ms/step - loss: 0.2287 - sensitivity_at_specificity: 0.8937 - val_loss: 0.2491 - val_sensitivity_at_specificity: 0.9531
# Epoch 5/50
# 219/219 [==============================] - 128s 583ms/step - loss: 0.2122 - sensitivity_at_specificity: 0.9090 - val_loss: 0.1417 - val_sensitivity_at_specificity: 0.9777
# Epoch 6/50
# 219/219 [==============================] - 129s 589ms/step - loss: 0.1963 - sensitivity_at_specificity: 0.9384 - val_loss: 0.2992 - val_sensitivity_at_specificity: 0.9754
# Epoch 7/50
# 219/219 [==============================] - 129s 588ms/step - loss: 0.1774 - sensitivity_at_specificity: 0.9259 - val_loss: 0.1260 - val_sensitivity_at_specificity: 0.9777
# Epoch 8/50
# 219/219 [==============================] - 128s 583ms/step - loss: 0.1754 - sensitivity_at_specificity: 0.9454 - val_loss: 0.1348 - val_sensitivity_at_specificity: 0.9683
# Epoch 9/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.1681 - sensitivity_at_specificity: 0.9694 - val_loss: 0.2172 - val_sensitivity_at_specificity: 0.9777
# Epoch 10/50
# 219/219 [==============================] - 128s 586ms/step - loss: 0.1432 - sensitivity_at_specificity: 0.9674 - val_loss: 0.1473 - val_sensitivity_at_specificity: 0.9789
# Epoch 11/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.1577 - sensitivity_at_specificity: 0.9623 - val_loss: 0.1343 - val_sensitivity_at_specificity: 0.9718
# Epoch 12/50
# 219/219 [==============================] - 128s 584ms/step - loss: 0.1429 - sensitivity_at_specificity: 0.9762 - val_loss: 0.1368 - val_sensitivity_at_specificity: 0.9789
# Epoch 13/50
# 219/219 [==============================] - 130s 593ms/step - loss: 0.1227 - sensitivity_at_specificity: 0.9788 - val_loss: 0.1372 - val_sensitivity_at_specificity: 0.9695
# Epoch 14/50
# 219/219 [==============================] - 128s 586ms/step - loss: 0.1209 - sensitivity_at_specificity: 0.9836 - val_loss: 0.1556 - val_sensitivity_at_specificity: 0.9660
# Epoch 15/50
# 219/219 [==============================] - 128s 587ms/step - loss: 0.1111 - sensitivity_at_specificity: 0.9835 - val_loss: 0.2125 - val_sensitivity_at_specificity: 0.9824
# Epoch 16/50
# 219/219 [==============================] - 129s 591ms/step - loss: 0.1693 - sensitivity_at_specificity: 0.9778 - val_loss: 0.1529 - val_sensitivity_at_specificity: 0.9730
# Epoch 17/50
# 219/219 [==============================] - 128s 586ms/step - loss: 0.0992 - sensitivity_at_specificity: 0.9931 - val_loss: 0.1869 - val_sensitivity_at_specificity: 0.9824
# Epoch 18/50
# 219/219 [==============================] - 129s 587ms/step - loss: 0.0929 - sensitivity_at_specificity: 0.9906 - val_loss: 0.1929 - val_sensitivity_at_specificity: 0.9800
# Epoch 19/50
# 219/219 [==============================] - 128s 585ms/step - loss: 0.1258 - sensitivity_at_specificity: 0.9894 - val_loss: 0.2056 - val_sensitivity_at_specificity: 0.9765
# Epoch 20/50
# 219/219 [==============================] - 128s 586ms/step - loss: 0.0867 - sensitivity_at_specificity: 0.9936 - val_loss: 0.1590 - val_sensitivity_at_specificity: 0.9754
# Epoch 21/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.0905 - sensitivity_at_specificity: 0.9895 - val_loss: 0.1832 - val_sensitivity_at_specificity: 0.9660
# Epoch 22/50
# 219/219 [==============================] - 132s 601ms/step - loss: 0.0742 - sensitivity_at_specificity: 0.9968 - val_loss: 0.2126 - val_sensitivity_at_specificity: 0.9789
# Epoch 23/50
# 219/219 [==============================] - 129s 591ms/step - loss: 0.0888 - sensitivity_at_specificity: 0.9953 - val_loss: 0.1805 - val_sensitivity_at_specificity: 0.9812
# Epoch 24/50
# 219/219 [==============================] - 128s 586ms/step - loss: 0.0956 - sensitivity_at_specificity: 0.9961 - val_loss: 0.5397 - val_sensitivity_at_specificity: 0.9789
# Epoch 25/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.0986 - sensitivity_at_specificity: 0.9968 - val_loss: 0.1855 - val_sensitivity_at_specificity: 0.9730
# Epoch 26/50
# 219/219 [==============================] - 129s 588ms/step - loss: 0.0805 - sensitivity_at_specificity: 0.9977 - val_loss: 0.1908 - val_sensitivity_at_specificity: 0.9789
# Epoch 27/50
# 219/219 [==============================] - 128s 587ms/step - loss: 0.0873 - sensitivity_at_specificity: 0.9964 - val_loss: 0.2638 - val_sensitivity_at_specificity: 0.9777
# Epoch 28/50
# 219/219 [==============================] - 131s 597ms/step - loss: 0.0542 - sensitivity_at_specificity: 0.9981 - val_loss: 0.2489 - val_sensitivity_at_specificity: 0.9824
# Epoch 29/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.0928 - sensitivity_at_specificity: 0.9984 - val_loss: 0.2947 - val_sensitivity_at_specificity: 0.9765
# Epoch 30/50
# 219/219 [==============================] - 130s 594ms/step - loss: 0.0618 - sensitivity_at_specificity: 0.9949 - val_loss: 0.2204 - val_sensitivity_at_specificity: 0.9707
# Epoch 31/50
# 219/219 [==============================] - 129s 589ms/step - loss: 0.0499 - sensitivity_at_specificity: 0.9992 - val_loss: 0.2403 - val_sensitivity_at_specificity: 0.9754
# Epoch 32/50
# 219/219 [==============================] - 129s 590ms/step - loss: 0.0453 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2459 - val_sensitivity_at_specificity: 0.9800
# Epoch 33/50
# 219/219 [==============================] - 130s 594ms/step - loss: 0.0460 - sensitivity_at_specificity: 0.9992 - val_loss: 0.2676 - val_sensitivity_at_specificity: 0.9789
# Epoch 34/50
# 219/219 [==============================] - 129s 589ms/step - loss: 0.0712 - sensitivity_at_specificity: 1.0000 - val_loss: 0.2402 - val_sensitivity_at_specificity: 0.9789
# Epoch 35/50
# 219/219 [==============================] - 130s 593ms/step - loss: 0.0389 - sensitivity_at_specificity: 0.9988 - val_loss: 0.3615 - val_sensitivity_at_specificity: 0.9695
# Epoch 36/50
# 219/219 [==============================] - 134s 611ms/step - loss: 0.0359 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2846 - val_sensitivity_at_specificity: 0.9754
# Epoch 37/50
# 219/219 [==============================] - 130s 594ms/step - loss: 0.0422 - sensitivity_at_specificity: 0.9988 - val_loss: 0.2605 - val_sensitivity_at_specificity: 0.9754
# Epoch 38/50
# 219/219 [==============================] - 129s 589ms/step - loss: 0.0502 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3799 - val_sensitivity_at_specificity: 0.9660
# Epoch 39/50
# 219/219 [==============================] - 129s 588ms/step - loss: 0.0254 - sensitivity_at_specificity: 1.0000 - val_loss: 0.2597 - val_sensitivity_at_specificity: 0.9742
# Epoch 40/50
# 219/219 [==============================] - 130s 594ms/step - loss: 0.0256 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3306 - val_sensitivity_at_specificity: 0.9789
# Epoch 41/50
# 219/219 [==============================] - 128s 584ms/step - loss: 0.0288 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3083 - val_sensitivity_at_specificity: 0.9754
# Epoch 42/50
# 219/219 [==============================] - 129s 589ms/step - loss: 0.0447 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3067 - val_sensitivity_at_specificity: 0.9789
# Epoch 43/50
# 219/219 [==============================] - 129s 591ms/step - loss: 0.0323 - sensitivity_at_specificity: 0.9981 - val_loss: 0.3186 - val_sensitivity_at_specificity: 0.9824
# Epoch 44/50
# 219/219 [==============================] - 129s 587ms/step - loss: 0.0478 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3135 - val_sensitivity_at_specificity: 0.9800
# Epoch 45/50
# 219/219 [==============================] - 130s 593ms/step - loss: 0.0267 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3146 - val_sensitivity_at_specificity: 0.9800
# Epoch 46/50
# 219/219 [==============================] - 128s 587ms/step - loss: 0.0182 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3489 - val_sensitivity_at_specificity: 0.9765
# Epoch 47/50
# 219/219 [==============================] - 130s 592ms/step - loss: 0.0076 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3569 - val_sensitivity_at_specificity: 0.9789
# Epoch 48/50
# 219/219 [==============================] - 129s 588ms/step - loss: 0.0539 - sensitivity_at_specificity: 0.9988 - val_loss: 0.3517 - val_sensitivity_at_specificity: 0.9777
# Epoch 49/50
# 219/219 [==============================] - 131s 596ms/step - loss: 0.0192 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3774 - val_sensitivity_at_specificity: 0.9730
# Epoch 50/50
# 219/219 [==============================] - 130s 595ms/step - loss: 0.0196 - sensitivity_at_specificity: 0.9988 - val_loss: 0.3416 - val_sensitivity_at_specificity: 0.9789
# Wall time: 1h 47min 43s

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'sensitivity_at_specificity', 'val_loss', 'val_sensitivity_at_specificity'])

# %%
sas = history.history['sensitivity_at_specificity']
val_sas = history.history['val_sensitivity_at_specificity']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(sas))

# %%
plot(epochs_range,sas,'bo-',label='Training sas')
plot(epochs_range,val_sas,'r*-',label='Validation sas')
title('Training and validation sas')
grid()
legend()

figure()
plot(epochs_range,loss,'bo-',label='Training loss')
plot(epochs_range,val_loss,'r*-',label='Validation loss')
title('Training and validation loss')
grid()
legend()

show()

# %%
model_file_dir = './models'
if not os.path.exists(model_file_dir):
    os.mkdir(model_file_dir)

count = len(os.listdir(model_file_dir)) + 1
print(count)

new_file_path = '%s/model_%03d_epochs_%d.h5' % (model_file_dir, count,  epochs)
print(new_file_path)

network.save(new_file_path)
# Out:
# 1
# ./models/model_001_epochs_50.h5

# %%
labels = test_generator.classes

# %%
# %%time
predicted = network.predict_generator(test_generator, workers=4)
# Out:
# Wall time: 12.5 s

# %%
plot(predicted, label='predicted')
plot(labels, 'r', label='True value')
legend()
xlabel('Case index')
grid()
show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve

print('Confusion matrix (machine learning way): ')
cm = confusion_matrix(labels, predicted > 0.5)
print(cm)
print('Confusion matrix (actual medicine way): ')
print(cm.T)
# Out:
# Confusion matrix (machine learning way):
# [[289  27]
#  [ 33 821]]
# Confusion matrix (actual medicine way):
# [[289  33]
#  [ 27 821]]

# %%
cr = classification_report(labels, predicted > 0.5, target_names=['Normal (0)','Pneumonia (1)'])
print(cr)
# Out:
#                precision    recall  f1-score   support
#
#    Normal (0)       0.90      0.91      0.91       316
# Pneumonia (1)       0.97      0.96      0.96       854
#
#      accuracy                           0.95      1170
#     macro avg       0.93      0.94      0.94      1170
#  weighted avg       0.95      0.95      0.95      1170

# %%
fpr, tpr, tresholds = roc_curve(labels, predicted, pos_label=1)

plot(fpr, tpr)
plot([0, 1], [0, 1], 'r:')
xlabel('False positive rate')
ylabel('True positive rate')
title('ROC curve')
xlim([0,1])
ylim([0,1])
grid()
show()
